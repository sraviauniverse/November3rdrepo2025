# %% [markdown]
# Welcome back!
#
# You can execute the cells using shift + enter
#
# Now, lets understand Tuples

# %% [markdown]
# ### Tuple
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and immutable.
#
# Tuples are written with round brackets.

# %%
t = ()
type(t)

# %%
t = ("apple", "banana", "cherry", "apple", "cherry")

# %%
print(t)

# %%
# Count() is used for counting the element of the tuple
t.count('apple')

# %%
# index() is used for accessing the element
t[2]

# %% [markdown]
# Slicing operator on tuple

# %% [markdown]
# I want to create a new tuple of elements from index 1 to 3

# %%
t2 =t[1:3]

# %%
print(t2)

# %%
type(t2)

# %% [markdown]
# Operators with tuple

# %%
print(t)
print(t2)

# %% [markdown]
# Now, I want to add 't' and 't2'

# %%
t3 = t + t2

# %%
print(t3)

# %% [markdown]
# I want to multiple the elemetnts in 't4'

# %%
t4 = t3*2

# %%
t4

# %% [markdown]
# In the above output, tuple t4 consists elements of t2 which are repeated 2 times

# %% [markdown]
# Now, lets compare two tuples, using comparsiosn operator. Here, element by element comparision takes place.

# %%
a= (1,2,3)
b=(1,2,3)
c=(1,2,4)

# %% [markdown]
# Comparing tuple 'a' and 'b'.

# %%
a == b

# %% [markdown]
# As both the tuples contain same elemets at the same indices, the resulant is true

# %%
a == c

# %% [markdown]
# As both the tuples doesn't contain same elemets at the same indices, the resulant is False

# %%
a > b

# %%
a >= b

# %% [markdown]
# What will be the output of c>a?

# %%
#Try yourself in this cell
