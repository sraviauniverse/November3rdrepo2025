# %% [markdown]
# Welcome to your first Python notebook!
#
# You can execute the cells using shift + enter

# %% [markdown]
# Notebooks are great as they allow us to execute small code blocks and finds error fast, rather than writing a program in a file and then using command line or IDE to execute it.

# %% [markdown]
# First, let's understand constants and variables. Constants are values that cannot be changed. For example, 42 remains 42 and "Hello World" remains "Hello World". Constant values can be assigned to variables, whose value we can change. For example, observe the difference between constants and variables in example below:

# %%
# this is a constant
42

# %% [markdown]
# We can use type() inbuilt function to find out the type of our constant.

# %%
type(42)

# %% [markdown]
# This is a number! Numbers are represented by int.

# %%
# this is a constant
"hello world"

# %% [markdown]
# Also observe how we used double quote (") while assigning the constant, but the cell output shows single quote ('). In Python, string values can be represented by both ' and ". We use them to our advantage when we need to print them.

# %% [markdown]
# What is the type of "hello world"?

# %%
# Fill this yourself

# %% [markdown]
# Now let's understand data types. You just saw two above- string and integers. There are more!

# %%
type(False)

# %%
type(3.14)

# %%
type(1 + 3j) # In complex numbers, the 2 dimensions are real and imaginary

# %%
type(type)

# %% [markdown]
# Python has a lot of types!

# %% [markdown]
# Variables can assume constants as their value. Variables are very useful as we can perform calculations on constants (and other variables), and store their values in variables again.

# %%
# variable can assume constant. You can use print to print values of variables or constants.
australia = "kangaroo"
print(australia)

# %%
australia = "Sydney"
print(australia)

# %%
australia = 1.023e-23
print(australia)

# %% [markdown]
# Variables can change their types also. However, what's this e? Its exponential format from mathematics. You may have observed it in calculators on multiplying large numbers.

# %%
10 - 1e1

# %%
100 - 1e2

# %%
0.001 + 1e-3

# %% [markdown]
# You can use operators to modify the constant values. Common operators are sum (+), subtract (-), multiple (*), get the remainder (%), get the  and power (**). We can of course, divide too, but let's check out the simple things first.

# %% [markdown]
# You can add numbers, floating points and booleans to each other. But wait, why boolean? Aren't they True or False?

# %%
print(True - 1)

# %%
print(False * 42)

# %%
a = 42
b = True
print(a * b)

# %% [markdown]
# You cannot add string to the numbers. You can expect an error if you try to add mismatching data types.

# %%
a = "hello"
b = 42
print(a+b)

# %% [markdown]
# You can add strings, but not multiply or subtract them. Don't worry too much about them at this stage, we will deal with strings in a separate lab.

# %%
a = "good"
b = "day"
print(a+b)

# %%
#error expected
a = "good"
b = "day"
print(a*b)

# %%
#error expected
a = "good"
b = "day"
print(a-b)

# %% [markdown]
# Challenge Activity:
#
# Create 2 variables named sun and moon. Store two values for temperature for sun and moon (However hot or cold you think they are). Find the difference between their temperature.

# %%
# write your code here

# %% [markdown]
# Challenge Activity:
#
# My wallet has 5 dollars. Paul gave me a dollar and Sarah gave me 2 dollars. Peter than took away three dollars from me. Assign each person a variable, and print how much money is left in my wallet.

# %%
# write your code here
